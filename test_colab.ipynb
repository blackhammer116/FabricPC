# %%
# !git clone https://github.com/blackhammer116/FabricPC.git
# %cd FabricPC
# !pip install -e ".[all]"
# !pre-commit install
# Out:
# Cloning into 'FabricPC'...
# remote: Enumerating objects: 2012, done.
# remote: Counting objects: 100% (826/826), done.
# remote: Compressing objects: 100% (390/390), done.
# remote: Total 2012 (delta 528), reused 614 (delta 436), pack-reused 1186 (from 1)
# Receiving objects: 100% (2012/2012), 1.39 MiB | 5.14 MiB/s, done.
# Resolving deltas: 100% (1336/1336), done.
# /content/FabricPC
# Obtaining file:///content/FabricPC
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 18.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 13.2 MB/s eta 0:00:00
# ...

# %%
# !git pull
# %cd FabricPC/
# !git checkout feature/mnist-linear-ns
# !python examples/mnist_navier_stokes_hj_ot.py
# Out:
# 2026-03-31 14:17:09.256506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774966629.276607   94064 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774966629.283142   94064 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774966629.299029   94064 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !git checkout feat/NavierStokes
# !python examples/mnist_navier_stokes_hj_ot.py
# !python examples/mnist_advanced.py --optimizer adamw
# Out:
# M	examples/mnist_navier_stokes_hj_ot.py
# M	examples/navier_stokes_best_variant.png
# Already on 'feat/NavierStokes'
# Your branch is up to date with 'origin/feat/NavierStokes'.
#
# 5 nodes, 4 edges, 242,762 parameters
# Optimizer: adamw
# 2026-03-31 10:53:27.561287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774954407.581828   38155 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774954407.588442   38155 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
